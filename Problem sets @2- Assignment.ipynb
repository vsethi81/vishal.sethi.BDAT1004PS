# %%
#sol 1
a = 0

def b(): 
   global a

   a = c(a)
def c(a):

 return a + 2

# %%
>>> b()
>>> b()
>>> b()
>>> a
# Out:
# 6

# %%
# sol 2
file_name = input('please enter the file name:')

def filelength(file_name):
    try:
      file = open(file_name)
      contents = file.read()
      file.close()
      print(len(contents))
    except FileNotFoundError:
      print( file_name +" not found!")
      
      
filelength(file_name)
# Out:
# please enter the file name:vishal
# vishal not found!

# %%
#Sol 3

#define class named Marsupial.
class Marsupial():
     #define function called __inti__ and give parameter MyObject.
     #Myobect is a precent instance of class
  def __init__(MyObject):
     #create a list to store items. 
    MyObject.list = []
     #define function put_in_pouch and give values for Myitem
  def put_in_pouch(MyObject, Myitem):
     #use append to add value to the list.
    MyObject.list.append(Myitem)
     #define pouch_content function
  def pouch_contents(MyObject):
    return MyObject.list
## creating the subclass of Marsupial named Kangaroo.
class Kangaroo(Marsupial):

  def __init__(MyObject,x,y):
  #extending the Marsupial __init__ constructor to take,
  #as input, the coordinates x and y of the Kangaroo object,
    Marsupial.__init__(MyObject)
    MyObject.x = x
    MyObject.y = y
   #using jump method 
  def jump(MyObject,dx,dy):
    MyObject.x += dx
    MyObject.y += dy
    #overloading the __str__ operator 
  def __str__(MyObject):

    return 'I am a Kangaroo located at coordinates ({},{})'.format(MyObject.x,MyObject.y)

# %%
>>> m = Marsupial()
>>> m.put_in_pouch('doll')
>>> m.put_in_pouch('firetruck')
>>> m.put_in_pouch('kitten')
>>> m.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %%
>>> k = Kangaroo(0,0)
>>> print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)

# %%
>>> k.jump(1,0)
>>> k.jump(1,0)
>>> k.jump(1,0)
>>> print(k)
# Out:
# I am a Kangaroo located at coordinates (3,0)

# %%
#Sol 4
def collatz(x):

    print(x)
    if x==1:
        return 
    elif x%2==0:
        return collatz(x//2)  
    else:
        return collatz(x*3+1)

# %%
>>> collatz(10)
10
5
16
8
4
2
1
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# 1

# %%
#Sol 5
def binary(n):
    if n < 2:
        print (n)
    else:
       num = ''
       while n > 0:
           num = str((n % 2)) + num
           n //= 2
       return num

# %%
>>> binary(0)
'0'
>>> binary(1)
'1'
>>> binary(2)
'01'
>>> binary(9)
'1001'
# Out:
# 0
# 1
# '1001'

# %%
#Sol 6
import re

from html.parser import HTMLParser



class MyHeadingParser(HTMLParser):

  def HeadingaOpenTag(MyObject, tag, attrs):

    global GetHeading

    ExextH = re.match(r'h(\d)', tag, re.I)

    if ExectH:
      print(match.group(1))

      GetHeading = int(match.group(1))

     

  def HeadingEndTag(MyObject, tag):

    ExectH = re.match(r'h(\d)', tag, re.I)
    if ExectH:
        
          print("Yay..Found an end tag :", tag)

          GetHeading = 0



  def HeadingData(MyObject, Data):

    if GetHeading > 0:

      tab = GetHeading - 1

      Output = "\t"*tab

      print(OutPut + data)



GetHeading = 0

parser = MyHeadingParser()

parser.feed('<html><head><title>Test</title></head>'

'<body><h1>head1</h1><h2>head2!</h2><h3>head3!</h3></body></html>')

# %%
#sol8
SELECT Tempreture from Table;
SELECT distinct City from Table;
SELECT* from Table where Country='India';
SELECT* from Table where Season='Fall';
SELECT City, Country where Rainfall >=200 and Rainfall <=400;
SELECT City, Country from Table where Temprature > 20 order by Temprature ASC;
SELECT count(rainfall) from Table where City='Cairo';
SELECT rainfall,count(rainfall) from Table group by Rainfall;
# Out:
#   Input In [14]
#     SELECT Tempreture from Table;
#            ^
# SyntaxError: invalid syntax

# %%
# sol9
#Question 9


words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

#(A)converting words into uppercase.
UpperCaselist = [w.upper() for w in words]

#b)converting words into lowercase
LowerCaselist = [w.lower() for w in words]

#c)show the length of each word
Lengthlist= [len(w) for w in words]

#D)Make a list where we can do lowercase, uppercase and count the words
LowerUpperLenList= [[w.upper(),w.lower(),len(w)] for w in words]

#E)the list of words in list words containing 4 or more characters
MoreChar = [i.lower() for i in words if len(i)>=4]

#print lists
print (UpperCaselist)
print (LowerCaselist)
print (Lengthlist)
print (LowerUpperLenList)
print (MoreChar)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
